# %%
import cv2
import mediapipe as mp
import time

# %%
mpHands = mp.solutions.hands
hands = mpHands.Hands()

# %%
cam = cv2.VideoCapture(0)

# %%
while True:
    success, img = cam.read()
    grayImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    result = hands.process(grayImg)
    print(result.multi_hand_landmarks)

    if not success:
        print("Failed")
        break
    cv2.imshow('videoCam',grayImg)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
