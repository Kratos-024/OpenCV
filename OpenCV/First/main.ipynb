# %%
import cv2

# %%
img_read = cv2.imread('test.jpeg')
print(img_read.shape)
# Out:
# (625, 863, 3)

# %%
cv2.imshow('new',img_read)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img_read[0]
# Out:
# array([[220, 218, 217],
#        [217, 215, 214],
#        [212, 210, 209],
#        ...,
#        [216, 219, 223],
#        [216, 219, 223],
#        [215, 218, 222]], shape=(863, 3), dtype=uint8)

# %%
img_read = cv2.imread('test.jpeg',0)
print(img_read.shape)
# Out:
# (625, 863)

# %%
cv2.imshow('new',img_read)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
rgb_im = cv2.cvtColor(img_read,cv2.COLOR_GRAY2RGB)

# %%
img_read = cv2.imread('test.jpeg')
print(img_read.shape)
rgb_im = cv2.cvtColor(img_read,cv2.COLOR_BGR2RGB)
cv2.imshow('new2',img_read)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (625, 863, 3)
